# %% [markdown]
# ## **File Handling**

# %% [markdown]
# ### **What is File Handling?**
# File handling in Python allows you to perform operations on files, such as reading, writing, appending, and deleting. It enables data persistence, as data stored in files can be accessed and modified later.
#
# ### **Types of Files:**
# - Text Files: Human-readable files like .txt and .csv.
# - Binary Files: Non-human-readable files like .jpg and .exe.
#
# ### **Why File Handling is Important:**
# - **Data Storage Beyond Program Execution:** Programs often need to store data beyond their runtime. Without file handling, any data generated during a program’s execution would be lost when the program terminates. File handling allows data to persist and be reused when needed.
# - **Handling Large Data Sets:** Many real-world applications deal with large volumes of data that cannot be fully processed in memory (RAM). File handling enables storing such data on disk, where it can be accessed and processed incrementally.
# - **Record Keeping and Logging:** Many applications require continuous logging or recording of events, errors, or user activities. Files are the standard way to store this information for later analysis, monitoring, and debugging.
# - **Flexibility in Data Formats:** File handling allows developers to choose the most suitable format for storing data (e.g., text, binary, CSV, JSON, XML). This flexibility supports a wide range of use cases, from simple text storage to complex data structures.
# - Process data from external sources like configuration files.
#
# ### **Opening and Closing Files**
#
# #### **Syntax**
# ```
# file = open('filename', mode)
# file.close()
# ```
#
# **Opening a file `open()`:**
#
# When the open() function is used to open a file, it returns a pointer to the beginning of the file. This is called a 'file handler' or 'file object.'
#
# **Closing a file `close()`:**
#
# A file which is opened should be closed using the close() method. Once a file is opened but not closed, then the data of the file may be corrupted or deleted in some cases. Also, if the file is not closed, the memory utilized by the file is not freed, leading to problems like insufficient memory. This happens when we are working with serval files simultaneously. Hence it is mandatory to close the file.
#
# `f.close()`
#
# ### Modes
#
#   -----> `r mode`:-   To read data from the file. The file pointer is positioned at the beginning of the file.
#
#  -----> `w mode`:-	To wirte data into file. If any data is already present in the file,it would be deleted and the present data will be stored.
#
#  -----> `r+ Mode`:- Opens the file for both reading and writing. The file pointer is placed at the beginning of the file. If the file does not exist, it raises a FileNotFoundError.
#
#  -----> `w+ mode`:-Opens the file for both reading and writing. The file is truncated (emptied) when opened. If the file does not exist, a new file is created.
#
#  -----> `a mode`: a  To append data to the file. Appending means adding at the end of existing data.The filepointer is placed at the end of the file.if the  file does not exist, it will create a new file for writing data.
#
#  -----> `a+ mode`: a+  To append and read data of a file.The file pointer will be at the end of the file if the file exists. If the file does not exist, it creates a new file for reading and writing.
#
#  -----> `b mode` Binary mode. Eg: 'rb', 'wb'

# %% [markdown]
# ## **Text File Handling**

# %%
## Creating a File
def creat_file(file_name, content):
    with open(file_name, 'w') as file:
        file.write(content)
creat_file('example.txt', 'Python is a powerful programming language.')

# %%
with open('example.txt', 'w') as file:
    file.write('Python is a Interpeter Language')
    file.close()

# %%
# Read the file

f = open("example.txt", "r")
content = f.read()
print(content)
f.close()
# Out:
# Python is a Interpeter Language

# %% [markdown]
# ### **Using with Statement**
# - Benifit : Automatically handles Closing files, even if errors occurs

# %%
with open(r'example.txt', 'r') as file:
    content = file.read()
    print(content)
    file.close()
# Out:
# Python is a Interpeter Language

# %%
file = open('example.txt', 'r')
content = file.read()
print(content)
file.close()
# Out:
# Python is a Interpeter Language

# %%
with open("example.txt", 'r+') as file:
    content = file.read()
    print(content)

    file.seek(0)

    file.write("Updated content at the beginning")

    file.seek(2)
    
    print(file.read())

    file.close()
# Out:
# Python is a Interpeter Language
# dated content at the beginning

# %%
with open("myfile.txt", "w") as file:
    file.write("This is a file")
    file.close()

# %%
with open("myfile.txt", 'r') as file:
    print(file.read())
    file.close()
# Out:
# This is a file

# %%
with open("myfile.txt", 'w+') as file:
    file.write("Python is a Interpeter Language")

    file.seek(1)

    print(file.read())

    file.close()
# Out:
# ython is a Interpeter Language

# %%
with open("myfile.txt", mode="a") as file:
    file.write("\nPython is High level Language")
    file.close()

# %%
f = open("myfile.txt", 'r')
content = f.read()
print(content)
f.close()
# Out:
# Python is a Interpeter Language
# Python is High level Language

# %%
with open("myfile.txt", mode="a") as file:
    file.write("\nPython is Dynamic Language")
    file.close()

# %%
with open("myfile.txt", mode='r') as s:
    content = s.read()
    print(content)
    s.close()
# Out:
# Python is a Interpeter Language
# Python is High level Language
# Python is Dynamic Language

# %%
with open("myfile.txt", mode='a+') as file:
    file.write("\nPython is Supports Oops Principle")

    file.seek(0)

    cont = file.read()
    print(cont)

    file.close()
# Out:
# Python is a Interpeter Language
# Python is High level Language
# Python is Dynamic Language
# Python is Supports Oops Principle

# %%
mixed_strings = [
    "test@example.com",
    "123-456-7890",
    "Start this string",
    "This string ends with End",
    "123456",
    "Contains whitespace ",
    "pretest and posttest",
    "@#!$%",
    "5This does not start with a digit",
    "NoWhitespaceHere"
]

def create_file(file_path, content):
    with open(file_path, mode='w') as file:
        for char in content:
            file.write(char+'\n')

create_file('String_file.txt', mixed_strings)

# %%
f = open('String_file.txt', 'r')
print(f.read())
f.close()
# Out:
# test@example.com
# 123-456-7890
# Start this string
# This string ends with End
# 123456
# Contains whitespace
# pretest and posttest
# @#!$%
# 5This does not start with a digit
# NoWhitespaceHere

# %%
## Readline and Readlins

file = open('String_file.txt', 'r')
content = file.readline()
print(content)
file.close()
# Out:
# test@example.com

# %%
file = open('String_file.txt', 'r')
content = file.readlines()
print(content)
file.close()
# Out:
# ['test@example.com\n', '123-456-7890\n', 'Start this string\n', 'This string ends with End\n', '123456\n', 'Contains whitespace \n', 'pretest and posttest\n', '@#!$%\n', '5This does not start with a digit\n', 'NoWhitespaceHere\n']

# %%
file = open('String_file.txt', 'r')
content = file.readlines()
for string in content:
    print(string.strip())
file.close()
# Out:
# test@example.com
# 123-456-7890
# Start this string
# This string ends with End
# 123456
# Contains whitespace
# pretest and posttest
# @#!$%
# 5This does not start with a digit
# NoWhitespaceHere

# %%
## Write and writelins

f = open('myfile.txt', mode='w')
f.writelines(['Python is a Interpeter Language',
'\nPython is High level Language',
'\nPython is Dynamic Language',
'\nPython is Supports Oops Principle'])
f.close()

# %%
with open('myfile.txt', mode='r') as f:
    print(f.read())
    f.close()
# Out:
# Python is a Interpeter Language
# Python is High level Language
# Python is Dynamic Language
# Python is Supports Oops Principle

# %%
with open('myfile.txt', mode='r') as f:
    print(f.read().split('\n'))
    f.close()
# Out:
# ['Python is a Interpeter Language', 'Python is High level Language', 'Python is Dynamic Language', 'Python is Supports Oops Principle']

# %%
with open('myfile.txt' ,'r') as file:
    with open('ouput.txt', 'w') as f:
        for line in file:
            f.write(line)

    f.close()
file.close()

# %%
f = open('ouput.txt', mode='r')
print(f.read())
f.close()
# Out:
# Python is a Interpeter Language
# Python is High level Language
# Python is Dynamic Language
# Python is Supports Oops Principle

# %% [markdown]
# ## **Handling Directory**

# %%
import os

# %%
os.mkdir('New_Folder')

# %%
os.rmdir('New_Folder')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 os.rmdir('New_Folder')
#
# PermissionError: [WinError 5] Access is denied: 'New_Folder'

# %%
os.remove("ouput.txt")

# %%
if os.path.exists('myfile.txt'):
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# ## ***Handling CSV file**

# %%
import csv

# %%
def create_file(file_path, content):
    with open(file_path, 'w') as file:
        file.write(content)

# %%
create_file('data.csv', 'Name,Age,City\nAsh,25,Blore\nArya,24,Jaipur')

# %%
with open('data.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
    file.close()
# Out:
# ['Name', 'Age', 'City']
# ['Ash', '25', 'Blore']
# ['Arya', '24', 'Jaipur']

# %%
with open('data.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Age', 'City'])
    writer.writerow(['Manvitha', '20', 'Balore'])
    writer.writerow(['Aftab idris', '24', 'Iran'])
    writer.writerow(['Deepak', '23', 'Hindupur'])
    writer.writerow(['Navya', '23', 'Baglore'])
    writer.writerow(['Poornima', '22', 'Baglore'])
    file.close()

# %%
with open('data.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
    file.close()
# Out:
# ['Name', 'Age', 'City']
# ['Manvitha', '20', 'Balore']
# ['Aftab idris', '24', 'Iran']
# ['Deepak', '23', 'Hindupur']
# ['Navya', '23', 'Baglore']
# ['Poornima', '22', 'Baglore']

# %%
with open('data.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Age', 'City'])
    writer.writerows([
        ['Alice', '30', 'New York'],
        ['Bob', '31', 'San Francisco'],
        ['Ash', '24', 'India']
    ])
    file.close()

# %%
with open('data.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
    file.close()
# Out:
# ['Name', 'Age', 'City']
# ['Alice', '30', 'New York']
# ['Bob', '31', 'San Francisco']
# ['Ash', '24', 'India']

# %%
with open('data.csv', mode='a', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Xyz', '19', 'Bangalore'])
    file.close()

# %%
with open('data.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
    file.close()
# Out:
# ['Name', 'Age', 'City']
# ['Alice', '30', 'New York']
# ['Bob', '31', 'San Francisco']
# ['Ash', '24', 'India']
# ['Xyz', '19', 'Bangalore']

# %%
with open('data.csv', mode='r+', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['MovieID', 'Movie_Name', 'Rating'])
    writer.writerows([
        ['1', 'Ramayana', '5'],
        ['2', 'Mission Mangalyan', '4'],
        ['3', 'Mission Imposible', '5'],
        ['4', 'Matrix', '4']
    ])
    
    file.seek(0)
    
    reader = csv.reader(file)
    for row in reader:
        print(row)

    file.close()
# Out:
# ['MovieID', 'Movie_Name', 'Rating']
# ['1', 'Ramayana', '5']
# ['2', 'Mission Mangalyan', '4']
# ['3', 'Mission Imposible', '5']
# ['4', 'Matrix', '4']

# %%
with open('data.csv', mode='w+', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['MovieID', 'Movie_Name', 'Rating'])
    writer.writerows([
        ['1', 'Ramayana', '5'],
        ['2', 'Mission Mangalyan', '4'],
        ['3', 'Mission Imposible', '5'],
        ['4', 'Matrix', '4'],
        ['5', 'GodFather', '4']
    ])
    
    file.seek(0)
    
    reader = csv.reader(file)
    for row in reader:
        print(row)

    file.close()
# Out:
# ['MovieID', 'Movie_Name', 'Rating']
# ['1', 'Ramayana', '5']
# ['2', 'Mission Mangalyan', '4']
# ['3', 'Mission Imposible', '5']
# ['4', 'Matrix', '4']
# ['5', 'GodFather', '4']

# %%
with open('data.csv', mode='a+', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['6', 'F1', '5'])
    
    file.seek(0)
    
    reader = csv.reader(file)
    for row in reader:
        print(row)

    file.close()
# Out:
# ['MovieID', 'Movie_Name', 'Rating']
# ['1', 'Ramayana', '5']
# ['2', 'Mission Mangalyan', '4']
# ['3', 'Mission Imposible', '5']
# ['4', 'Matrix', '4']
# ['5', 'GodFather', '4']
# ['6', 'F1', '5']

# %%
with open('data.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        if row['Rating'] == '5':
            print(row['Movie_Name'], row['Rating'])
# Out:
# Ramayana 5
# Mission Imposible 5
# F1 5

# %%
import pandas as pd
# pip instll pandas

# %%
df = pd.read_csv('data.csv')
df
# Out:
#    MovieID         Movie_Name  Rating
# 0        1           Ramayana       5
# 1        2  Mission Mangalyan       4
# 2        3  Mission Imposible       5
# 3        4             Matrix       4
# 4        5          GodFather       4
# 5        6                 F1       5

# %% [markdown]
# ## **Handling Json File**

# %%
import json

# %%
create_file('data.json', '{"ID":"1", "Fruite":"Mango", "Color":"Orange"}')

# %%
with open('data.json', mode='r') as file:
    data = json.load(file)
    print(data)
    file.close()
# Out:
# {'ID': '1', 'Fruite': 'Mango', 'Color': 'Orange'}

# %%
with open('data.json', mode='w') as file:
    data = json.dump('{"ID":"1", "Fruite":"Apple", "Color":"Red"}',file, indent=4)
    file.close()

# %%
with open('data.json', mode='r') as file:
    data = json.load(file)
    print(data)
    file.close()
# Out:
# {"ID":"1", "Fruite":"Apple", "Color":"Red"}

# %%
data = [
    {"ID":"1", "Fruite":"Mango", "Color":"Orange"},
    {"ID":"2", "Fruite":"Apple", "Color":"Red"},
    {"ID":"3", "Fruite":"Jack Fruite", "Color":"Pale Yellow"},
    {"ID":"4", "Fruite":"Straw Berrey", "Color":"Red"},
    {"ID":"5", "Fruite":"Cherry", "Color":"Maroown"}
]

with open('data.json', mode='w') as file:
    data = json.dump(data,file, indent=4)
    file.close()

# %%
with open('data.json', mode='r') as file:
    data = json.load(file)
    print(data)
    file.close()
# Out:
# [{'ID': '1', 'Fruite': 'Mango', 'Color': 'Orange'}, {'ID': '2', 'Fruite': 'Apple', 'Color': 'Red'}, {'ID': '3', 'Fruite': 'Jack Fruite', 'Color': 'Pale Yellow'}, {'ID': '4', 'Fruite': 'Straw Berrey', 'Color': 'Red'}, {'ID': '5', 'Fruite': 'Cherry', 'Color': 'Maroown'}]

# %%
with open('data.json', mode='r') as file:
    data = file.read() #read txt format
    print(data)
    file.close()
# Out:
# [
#     {
#         "ID": "1",
#         "Fruite": "Mango",
#         "Color": "Orange"
#     },
#     {
#         "ID": "2",
#         "Fruite": "Apple",
#         "Color": "Red"
#     },
#     {
#         "ID": "3",
#         "Fruite": "Jack Fruite",
#         "Color": "Pale Yellow"
#     },
#     {
#         "ID": "4",
#         "Fruite": "Straw Berrey",
#         "Color": "Red"
#     },
#     {
#         "ID": "5",
#         "Fruite": "Cherry",
#         "Color": "Maroown"
#     }
# ]

# %%
with open('data.json', mode='r') as file:
    data = json.load(file)

    for fruit in data:
        print(fruit['Fruite'], fruit['Color'])
# Out:
# Mango Orange
# Apple Red
# Jack Fruite Pale Yellow
# Straw Berrey Red
# Cherry Maroown

# %%
new_data = {"ID":"6", "Fruite":"kiwi", "Color":"Green"}
data.append(new_data)
data
# Out:
# [{'ID': '1', 'Fruite': 'Mango', 'Color': 'Orange'},
#  {'ID': '2', 'Fruite': 'Apple', 'Color': 'Red'},
#  {'ID': '3', 'Fruite': 'Jack Fruite', 'Color': 'Pale Yellow'},
#  {'ID': '4', 'Fruite': 'Straw Berrey', 'Color': 'Red'},
#  {'ID': '5', 'Fruite': 'Cherry', 'Color': 'Maroown'},
#  {'ID': '6', 'Fruite': 'kiwi', 'Color': 'Green'}]

# %%
with open('data.json', mode='w') as file:
    data = json.dump(data,file, indent=4)
    file.close()

# %%
with open('data.json', mode='r') as file:
    data = json.load(file)
    print(data)
    file.close()
# Out:
# [{'ID': '1', 'Fruite': 'Mango', 'Color': 'Orange'}, {'ID': '2', 'Fruite': 'Apple', 'Color': 'Red'}, {'ID': '3', 'Fruite': 'Jack Fruite', 'Color': 'Pale Yellow'}, {'ID': '4', 'Fruite': 'Straw Berrey', 'Color': 'Red'}, {'ID': '5', 'Fruite': 'Cherry', 'Color': 'Maroown'}, {'ID': '6', 'Fruite': 'kiwi', 'Color': 'Green'}]

# %%
data = [{"ID":"1", "Fruite":"Mango", "Color":"Orange"}]

with open('data.json', mode='w+', encoding='utf-8') as file:
    json.dump(data, file, indent=4)

    file.seek(0)

    data = json.load(file)
    print(data)
    file.close()
# Out:
# [{'ID': '1', 'Fruite': 'Mango', 'Color': 'Orange'}]

# %%
with open('data.json', mode='w+', encoding='utf-8') as file:

    data[0]["Fruite"] = "Orange"
    json.dump(data, file, indent=4)

    file.seek(0)

    content = file.read()
    print(content)
    file.close()
# Out:
# [
#     {
#         "ID": "1",
#         "Fruite": "Orange",
#         "Color": "Orange"
#     }
# ]

# %%
new_data = {"ID":"2", "Fruite":"Apple", "Color":"Red"}
data.append(new_data)

# %%
data
# Out:
# [{'ID': '1', 'Fruite': 'Orange', 'Color': 'Orange'},
#  {'ID': '2', 'Fruite': 'Apple', 'Color': 'Red'}]

# %%
with open('data.json', mode='w+', encoding='utf-8') as file:
    json.dump(data, file, indent=4)

    file.seek(0)

    data = json.load(file)
    print(data)
    file.close()
# Out:
# [{'ID': '1', 'Fruite': 'Orange', 'Color': 'Orange'}, {'ID': '2', 'Fruite': 'Apple', 'Color': 'Red'}]

# %%
# Alternative Method resd the Json File
df =  pd.read_json('data.json')
df
# Out:
#    ID  Fruite   Color
# 0   1  Orange  Orange
# 1   2   Apple     Red

# %% [markdown]
# ## **Handling Binary files**

# %%
with open('Example.jpg', mode='rb') as file:
    content = file.read()
    print(content)
    file.close()
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\x0b\x08\x08\n\x08\x07\x0b\n\t\n\r\x0c\x0b\r\x11\x1c\x12\x11\x0f\x0f\x11"\x19\x1a\x14\x1c)$+*($\'\'-2@7-0=0\'\'8L9=CEHIH+6OUNFT@GHE\x01\x0c\r\r\x11\x0f\x11!\x12\x12!E.\'.EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE\xff\xc2\x00\x11\x08\x06\xb6\t\xb2\x03\x01\x11\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x004`|r\xa7\x98\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x80A\x02\x04\x08\x10 @\x81\x02\x04\x08\x10(, PXPX@\xa0\xa0\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x0f\x0f\xad\xa7\xe9\x13\xf8eO\x90d\x08\x10 @\x81\x02\x04\x08\x11\x10#"#" FDFDFD@\x8c\x88\x8c\x88\x81\x19\x11\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 FX\xa8v*\x1d\x8a\x05\x0e\xc5C\xb1@\xa1\xd8\xa8v(\x14;\x15\x0e\xc5\x02\x87b\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10\x08\x1c:\x0b\x08\x10\x04\x08 @\xa0\xb0\xa0\xb0\xa0\xb0\x80!a` A\x00@\x80A"\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x1b\x87\xf7x\xaf\x8a\xd4\xf0\xd9b\xa4\xe0F@\x81\x02\x04\x08\x88\x11\x90 @\x88\x8c\x81\x02\x04Dd\x0b\x15\x0e\x04\x08\x16*\x1c\x08\x88\xcb\x15\x0e\x04Dd\x0b\x15\x0e"2\x04Dd\x08\x16*\x1c\x08\x10,T8\x10 X\xa8p @\xb1P\xe0@\xb1@\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 0k\x14\x07\x8d\x021\x80\xa0@\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x01\x01\x8dB\x81\x02\x01\x8c\x05\x02\x04\x08\x10 @\x81\x00\xc6\x02 \x10 \xa0\xa0\xb0\xa0\x81\x00\x82\x00\x84\x0b\n\x0b\x0b\x01\x08\x10 @\xd0<\xe2\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @1\xb0 X\x084;\xf3^n\xa6\x05\x84\n\x08\x16\x14\x10, PX@\xa0\xb0\x80 a\x9cP @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @p\xf6\x00#\x03P @\x81\x02\x04\x08\r\x1a\x84\xd1\xa8P @\xfbl_\xcbjx\x8dzU{\x13\xa1\xf9J\xcfJm\x01\x00\x0c\xedZ\x10\xd4\x0e\xda\xa6\x06p\xd6\x1c\x91t\x07\xcf\x103\xd6M\xf9\x878\\\xb8v\x87\x0f3ZS\x11dk\xdeN\xbe5\xe6\xb6=<\xcdiLE@\xb6zI\xbe\x13\x8cMw\x15\xe0\x16Q< \x00g\x08\xc8\x11\x11\x91\x11\x90"#"# DFDFX\xa0@\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x03rm\x06\x00\x066lFff\x15\x8f\xa8\x8clj3\xb0\x01B\xd0:\x0b\x06\xa33\x1a\x00\x0fF&\x9a6\x03\x11\x99\x8a\x17}>S5!\x00,P<\x12\x04\x00\x16\x04\x106 \x0333\x8b\xac1A3\x00X@\xd2\x8clxd\x16\xa1\xe4\x11\x8fb\x16\xc7 \x01\x0c\xd6\x18\x83j9\xad@h\xf6\x00#3 nFF5\x02\xcb\n\x01\x03\x04\x87E\x18\x19\x038\x9a6\x05\x04\x01\x07\x05\xa3\x13P @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x0 ...

# %%
with open('Example.jpg', mode='rb') as file:
    content = file.read()

with open('copy.jpg', mode='wb') as file1:
    file1.write(content)

with open('copy.jpg', mode='rb') as copy_file:
    copy_content = copy_file.read()
    print(copy_content)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\x0b\x08\x08\n\x08\x07\x0b\n\t\n\r\x0c\x0b\r\x11\x1c\x12\x11\x0f\x0f\x11"\x19\x1a\x14\x1c)$+*($\'\'-2@7-0=0\'\'8L9=CEHIH+6OUNFT@GHE\x01\x0c\r\r\x11\x0f\x11!\x12\x12!E.\'.EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE\xff\xc2\x00\x11\x08\x06\xb6\t\xb2\x03\x01\x11\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x004`|r\xa7\x98\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x80A\x02\x04\x08\x10 @\x81\x02\x04\x08\x10(, PXPX@\xa0\xa0\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x0f\x0f\xad\xa7\xe9\x13\xf8eO\x90d\x08\x10 @\x81\x02\x04\x08\x11\x10#"#" FDFDFD@\x8c\x88\x8c\x88\x81\x19\x11\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 FX\xa8v*\x1d\x8a\x05\x0e\xc5C\xb1@\xa1\xd8\xa8v(\x14;\x15\x0e\xc5\x02\x87b\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10\x08\x1c:\x0b\x08\x10\x04\x08 @\xa0\xb0\xa0\xb0\xa0\xb0\x80!a` A\x00@\x80A"\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x1b\x87\xf7x\xaf\x8a\xd4\xf0\xd9b\xa4\xe0F@\x81\x02\x04\x08\x88\x11\x90 @\x88\x8c\x81\x02\x04Dd\x0b\x15\x0e\x04\x08\x16*\x1c\x08\x88\xcb\x15\x0e\x04Dd\x0b\x15\x0e"2\x04Dd\x08\x16*\x1c\x08\x10,T8\x10 X\xa8p @\xb1P\xe0@\xb1@\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 0k\x14\x07\x8d\x021\x80\xa0@\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x01\x01\x8dB\x81\x02\x01\x8c\x05\x02\x04\x08\x10 @\x81\x00\xc6\x02 \x10 \xa0\xa0\xb0\xa0\x81\x00\x82\x00\x84\x0b\n\x0b\x0b\x01\x08\x10 @\xd0<\xe2\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @1\xb0 X\x084;\xf3^n\xa6\x05\x84\n\x08\x16\x14\x10, PX@\xa0\xb0\x80 a\x9cP @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @p\xf6\x00#\x03P @\x81\x02\x04\x08\r\x1a\x84\xd1\xa8P @\xfbl_\xcbjx\x8dzU{\x13\xa1\xf9J\xcfJm\x01\x00\x0c\xedZ\x10\xd4\x0e\xda\xa6\x06p\xd6\x1c\x91t\x07\xcf\x103\xd6M\xf9\x878\\\xb8v\x87\x0f3ZS\x11dk\xdeN\xbe5\xe6\xb6=<\xcdiLE@\xb6zI\xbe\x13\x8cMw\x15\xe0\x16Q< \x00g\x08\xc8\x11\x11\x91\x11\x90"#"# DFDFX\xa0@\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x03rm\x06\x00\x066lFff\x15\x8f\xa8\x8clj3\xb0\x01B\xd0:\x0b\x06\xa33\x1a\x00\x0fF&\x9a6\x03\x11\x99\x8a\x17}>S5!\x00,P<\x12\x04\x00\x16\x04\x106 \x0333\x8b\xac1A3\x00X@\xd2\x8clxd\x16\xa1\xe4\x11\x8fb\x16\xc7 \x01\x0c\xd6\x18\x83j9\xad@h\xf6\x00#3 nFF5\x02\xcb\n\x01\x03\x04\x87E\x18\x19\x038\x9a6\x05\x04\x01\x07\x05\xa3\x13P @\x81\x02\x04\x08\x10 @\x81\x02\x04\x08\x10 @\x81\x02\x04\x0 ...

# %%
from PIL import Image

# %%
# pip install Pillow

# %%
img = Image.open('Example.jpg')
img.show()

# %%
resize = img.resize((300,300))
resize.show()

# %%
resize.save('Image_resize.jpg')

# %%
from IPython.display import display

img = Image.open('Image_resize.jpg')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300>
