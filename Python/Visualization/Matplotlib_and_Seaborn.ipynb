# %% [markdown]
# ## **Matplotlib**

# %%
#pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib

# %%
print(matplotlib.__doc__)
# Out:
# An object-oriented plotting library.
#
# A procedural interface is provided by the companion pyplot module,
# which may be imported directly, e.g.::
#
#     import matplotlib.pyplot as plt
#
# or using ipython::
#
#     ipython
#
# at your terminal, followed by::
#
#     In [1]: %matplotlib
#     In [2]: import matplotlib.pyplot as plt
#
# at the ipython shell prompt.
#
# For the most part, direct use of the explicit object-oriented library is
# encouraged when programming; the implicit pyplot interface is primarily for
# working interactively. The exceptions to this suggestion are the pyplot
# functions `.pyplot.figure`, `.pyplot.subplot`, `.pyplot.subplots`, and
# `.pyplot.savefig`, which can greatly simplify scripting.  See
# :ref:`api_interfaces` for an explanation of the tradeoffs between the implicit
# and explicit interfaces.
#
# Modules include:
#
# :mod:`matplotlib.axes`
#     The `~.axes.Axes` class.  Most pyplot functions are wrappers for
# ...

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm

# %%
x = np.arange(-3,3,0.1)
y = norm.pdf(x)

# %%
df = pd.DataFrame({"x":x,"y":y})
df.head()
# Out:
#      x         y
# 0 -3.0  0.004432
# 1 -2.9  0.005953
# 2 -2.8  0.007915
# 3 -2.7  0.010421
# 4 -2.6  0.013583

# %%
x = df['x']
y = df['y']
plt.scatter(x,y)
plt.title('Normal Distribution')
plt.show()

# %%
df[['x','y']].plot(kind='scatter', x='x', y='y', c='red') # color
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
plt.plot(x,y)
plt.show()

# %%
df[['x','y']].plot(kind='line', x='x', y='y', c='red')
# Out:
# <Axes: xlabel='x'>

# %% [markdown]
# ### **Multiple plots in one Graph**

# %%
plt.scatter(x,y)
plt.plot(x, norm.pdf(x, 1, 0.5))
plt.show()

# %% [markdown]
# ### **Save the Graph**

# %%
plt.scatter(x,y, c='c')
plt.plot(x, norm.pdf(x, 1,0.5), c='g')
plt.savefig(r"C:\Users\Admin\Downloads\Stats\plot.png", format='png')

# %% [markdown]
# ### **Customization of plots**

# %%
#custom of axis values
plt.scatter(x,y, c='c')
plt.plot(x, norm.pdf(x, 1,0.5), c='g')

plt.xlim([-4,4])
plt.ylim([0,1.2])

plt.show()

# %%
plt.scatter(x,y, c='y')
plt.plot(x, norm.pdf(x, 1,0.5), c='g')

plt.xticks([-3, 0 , 1, 3])
plt.yticks([0.4, 0.8, 0])

plt.xticks(rotation=90)

plt.show()

# %%
plt.scatter(x,y, c='c')
plt.plot(x, norm.pdf(x, 1,0.5), c='g')

plt.grid(linestyle='--', linewidth=1.2, axis='both', color='k') #liinestyle = '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'

plt.show()

# %%
plt.scatter(x,y, c='c', label='Scatter plot')
plt.plot(x, norm.pdf(x, 1,0.5), c='g', label='Line Plot')

plt.grid()

plt.xlabel('Even1', size=15, color='Blue', fontweight='bold', fontname='Times New Roman')
plt.ylabel('Even2')

plt.show()

# %%
plt.scatter(x,y, c='c', label='Scatter plot')
plt.plot(x, norm.pdf(x, 1,0.5), c='g', label='Line Plot')

plt.legend(loc='best') #'best', 'upper left', 'upper right', 'lower left', 'lower right', 1, 2,3,4, 'center left', 'center right', 'lower center', 'upper center', 'center'

plt.show()

# %%
plt.scatter(x,y, c='c', label='Scatter plot')
plt.plot(x, norm.pdf(x, 1,0.5), c='g', label='Line Plot')

plt.legend()

plt.annotate('This ia plot', xy=(0,0.4), xytext=(-2.0,0.7), arrowprops = dict(facecolor='black'))

plt.show()

# %%
plt.scatter(x,y, c='c', label='Scatter plot')
plt.plot(x, norm.pdf(x, 1,0.5), c='g', label='Line Plot')

plt.title('Dirtibution Graph', size=12, fontweight='bold', fontname='Times New Roman')

plt.show()

# %% [markdown]
# ### **Customization of scatter plot**

# %%
plt.scatter(x,y, c='c', label='Scatter plot 1', marker='*', s=100, edgecolor='black', alpha=0.7) # marker '.', 'o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X'
plt.scatter(x, norm.pdf(x, 1,0.5), c='g', label='Scatter Plot 2', marker='>')

plt.xticks([-3,0,1,3])

plt.grid()

plt.xlabel('Event1')
plt.ylabel('Event2')

plt.legend(loc=2)

plt.title("Scatter Plot")

plt.show()

# %% [markdown]
# ### **Customization Line Graph**

# %%
plt.plot(x,y, color='blue', linestyle='-.', linewidth=1.5, label = 'Line plot1')
plt.plot(x, norm.pdf(x, 1,0.5), c='y', marker='*', label='Line plot 2')
plt.plot(x, norm.pdf(x, 2 , 0.5), 'g+', label='Line plot 3')

plt.xticks([-3,0,1,2,3])

plt.grid(axis='both', linestyle=':')

plt.xlabel('Even1')
plt.ylabel('Even2')

plt.legend(title='line plots')

plt.title("Line Graph")

plt.show()

# %% [markdown]
# ### **Pie Chart**

# %%
values =[12,30, 4, 32, 14]

labels = ['A', 'B', 'C', 'D', 'E']

colors = ['red', 'blue', 'green', 'cyan', 'm']

explode = [0,0.1,0,0.2,0]

plt.pie(values, labels=labels,autopct='%1.f%%', radius=0.7, colors=colors, explode=explode)

plt.legend(title='Label')

plt.title('Pie Chart')

plt.show()

# %% [markdown]
# ### **Bar Plot**

# %%
x = ['A', 'B', 'C', 'D', 'E']
y = [10,20,30,40,25]

plot = plt.bar(x,y, color=['r', 'g', 'b', 'm', 'y'], edgecolor='k')
plt.bar_label(plot, label_type='center', rotation=90, fmt='%.1f')

plt.plot(x,y, marker='*', color='r')

plt.xlabel('X Label')
plt.ylabel('Y Label')

plt.grid(axis='both')

plt.legend(plot, x)

plt.title("Vertical Bar chart")

plt.show()

# %%
x = ['A', 'B', 'C', 'D', 'E']
y = [10,20,30,40,25]

plot = plt.barh(x,y, color=['r', 'g', 'b', 'm', 'y'], edgecolor='k')
plt.bar_label(plot, label_type='center', rotation=90, fmt='%.1f')

plt.xlabel('Y Label')
plt.ylabel('X Label')

plt.grid(axis='both')

plt.legend(plot, x)

plt.title("Horizontal Bar chart")

plt.show()

# %% [markdown]
# ### **Histogram**

# %%
data = np.random.randn(1000)

plt.hist(data, edgecolor='k', bins=10, color='blue', alpha=0.5, histtype='bar', orientation='vertical')

plt.ylabel('Frequency')
plt.xlabel('Values')

plt.title('Histogram')
plt.show()

# %% [markdown]
# ### **Density Plot**

# %%
import pandas as pd
df = pd.DataFrame(data, columns=['Data'])
df.head()
# Out:
#        Data
# 0  1.630227
# 1  0.890540
# 2 -0.128692
# 3 -0.605990
# 4 -1.108080

# %%
df['Data'].plot(kind='kde', linestyle=':', color='r', linewidth=2)
plt.show()

# %% [markdown]
# ### **box or whisker plot**
#
# <pre><code>     Q1-1.5IQR   Q1   median  Q3   Q3+1.5IQR
#                   |-----:-----|
#   o      |--------|     :     |--------|    o  o
#                   |-----:-----|
# flier             <----------->            fliers
#                        IQR</code></pre>

# %%
import pandas as pd
uniformSkewed = np.random.rand(100) * 100 - 40
high_outliers = np.random.rand(10) * 50 + 100
low_outliers = np.random.rand(10) * -50 - 100

data = np.concatenate((uniformSkewed, high_outliers, low_outliers))

df = pd.DataFrame({'data': data})
df.head()
# Out:
#         data
# 0   3.765553
# 1  32.891356
# 2 -26.941125
# 3   7.744167
# 4 -37.308662

# %%
df.describe()
# Out:
#              data
# count  120.000000
# mean     8.097627
# std     58.020067
# min   -148.448003
# 25%    -19.163809
# 50%     11.601631
# 75%     38.746282
# max    130.957578

# %%
plt.boxplot(df['data'], vert=False, showfliers=True, meanline=True, labels=df.columns)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5616\2694052802.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(df['data'], vert=False, showfliers=True, meanline=True, labels=df.columns)

# %% [markdown]
# ### **Subplot**

# %%
x = np.arange(-3,3,0.1)
data = np.random.randn(1000)

plt.figure(figsize=(8,6))

plt.subplot(2,2,1)
plt.plot(x, norm.pdf(x), c='b', linestyle='--')
plt.xticks([-3,0,1,-4])
plt.title('Line Plot')

plt.subplot(2,2,2)
plt.scatter(x, norm.pdf(x, 1, 0.5), c='y', marker='*')
plt.grid(axis='both')
plt.title('Scatter plot')
plt.title("Histogram")

plt.subplot(223)
plt.hist(data, bins=10, color='g', edgecolor='k', alpha=0.7)
plt.xlabel('Data')
plt.ylabel('Frequency')

plt.subplot(224)
plt.boxplot(data, vert=False, patch_artist=True)
plt.xlabel('Event1')
plt.title('Boxplot')

plt.tight_layout()

plt.show()

# %% [markdown]
# ## **Seaborn**

# %%
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# pip install seaborn

# %%
dir(sns)
# Out:
# ['FacetGrid',
#  'JointGrid',
#  'PairGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_base',
#  '_compat',
#  '_core',
#  '_docstrings',
#  '_orig_rc_params',
#  '_statistics',
#  '_stats',
#  'algorithms',
#  'axes_style',
#  'axisgrid',
#  'barplot',
#  'blend_palette',
#  'boxenplot',
#  'boxplot',
#  'categorical',
#  'catplot',
#  'choose_colorbrewer_palette',
#  'choose_cubehelix_palette',
#  'choose_dark_palette',
#  'choose_diverging_palette',
#  'choose_light_palette',
#  'clustermap',
#  'cm',
#  'color_palette',
#  'colors',
#  'countplot',
#  'crayon_palette',
#  'crayons',
#  'cubehelix_palette',
#  'dark_palette',
#  'desaturate',
#  'despine',
#  'displot',
#  'distplot',
#  'distributions',
#  'diverging_palette',
#  'dogplot',
#  'ecdfplot',
#  'external',
#  'get_data_home',
#  'get_dataset_names',
#  'heatmap',
#  'histplot',
# ...

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Data Exploration
df.shape
# Out:
# (244, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df.describe(include='category').T
# Out:
#        count unique     top freq
# sex      244      2    Male  157
# smoker   244      2      No  151
# day      244      4     Sat   87
# time     244      2  Dinner  176

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# data cleaning
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)

# %%
df.groupby('day').agg({'tip':'mean'}).reset_index()
# Out:
#     day       tip
# 0  Thur  2.784098
# 1   Fri  2.734737
# 2   Sat  2.993103
# 3   Sun  3.255132

# %%
df.groupby('sex')['tip'].sum()
# Out:
# sex
# Male      485.07
# Female    244.51
# Name: tip, dtype: float64

# %% [markdown]
# ### **Data Visualization**

# %% [markdown]
# ### **1. BarPlot**
# - display distribution of categorical data

# %%
df.groupby('day')['tip'].mean()
# Out:
# day
# Thur    2.784098
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %%
sns.color_palette('afmhot_r')
# Out:
# [(1.0, 1.0, 0.7176470588235295),
#  (1.0, 0.9274509803921569, 0.4274509803921569),
#  (1.0, 0.6450980392156862, 0.1450980392156862),
#  (0.8549019607843138, 0.3549019607843138, 0.0),
#  (0.5725490196078431, 0.0725490196078431, 0.0),
#  (0.2823529411764707, 0.0, 0.0)]

# %% [markdown]
# ##### **Palette**
#
# **palatte**
#
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'

# %%
ax = sns.barplot(x='day', y='tip', data=df, estimator='mean', errorbar=None, palette='Set1')
ax.bar_label(ax.containers[0])
plt.grid(axis='both')
plt.xlabel("Days")
plt.ylabel("Tips")
plt.title("Tips by Day")
plt.show()

# %% [markdown]
# ### **2. Countplot**

# %%
df.groupby(['sex', 'day'])['day'].count()
# Out:
# sex     day
# Male    Thur    30
#         Fri     10
#         Sat     59
#         Sun     58
# Female  Thur    31
#         Fri      9
#         Sat     28
#         Sun     18
# Name: day, dtype: int64

# %%
sns.countplot(x='day', data=df, hue='sex', palette='Greens')
plt.grid()
plt.title('Count of Days by Gender')
plt.show()

# %% [markdown]
# ### **3. Pie Chart**

# %%
smoker = df['smoker'].value_counts()
smoker
# Out:
# smoker
# No     151
# Yes     92
# Name: count, dtype: int64

# %%
plt.pie(smoker, labels=smoker.index, autopct='%1.f%%', explode=[0,0.1], colors=sns.color_palette('Set2'))
plt.legend()
plt.title("Ditribution of Smoker")
plt.show()

# %% [markdown]
# ### **4. Scatter Plot**

# %%
sns.scatterplot(x='total_bill', y='tip', data=df, marker='o', size='size', sizes=(20,200), edgecolor='k', alpha=0.7)
plt.title("Relation between total_bill and tip")
plt.show()

# %% [markdown]
# ### **5. Line Plot**

# %%
sns.lineplot(x=df['day'], y='tip', data=df, linestyle='--', marker='*', markersize=15, hue='sex', palette='Set1')
plt.title('totla_bill vs Day')
plt.show()

# %% [markdown]
# ### **6. Boxplot or wisker plot**

# %%
sns.boxplot(y='total_bill', data=df, palette='Greens', fill=True)
plt.title('Distribution of total_bills')
plt.show()

# %% [markdown]
# ### **7. Density Plot**

# %%
sns.distplot(df['total_bill'], color='b', hist=True, bins=10, kde=True)
plt.title('Distribution of totla bill')
plt.show()

# %%
sns.kdeplot(x='total_bill', data=df, hue = 'sex', shade='True')
plt.title("Distribution of total bill")
plt.show()

# %%
sns.histplot(x='tip', data= df, bins=20, palette='Set3')
plt.title("Ditribution of tips")
plt.show()

# %% [markdown]
# ### **8. Pairplot**

# %%
sns.pairplot(df, hue='time', kind='scatter') # "scatter", "reg", "kde", "hex"
plt.suptitle('Correlation Between Multiple Veriable', y=1.05, x=0.5)
plt.show()

# %% [markdown]
# ### **9. Heatmap**

# %%
numarical = df.select_dtypes(include=['int', 'float']).columns.tolist()
numarical
# Out:
# ['total_bill', 'tip', 'size']

# %%
co_relation = df[numarical].corr()
co_relation
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.674998  0.597589
# tip           0.674998  1.000000  0.488400
# size          0.597589  0.488400  1.000000

# %%
sns.heatmap(co_relation, annot=True, cmap='PuBu')
plt.title('co relationn b/w the veriables')
plt.show()

# %% [markdown]
# ### **10. Violin Plot**

# %%
sns.violinplot( data=df, palette='Set2')
plt.title("Total billditribution")
plt.show()

# %% [markdown]
# ### **11. Joint plot**

# %%
sns.jointplot(x='total_bill', y='tip', data=df,color='red', kind='hist') # kde | hist | hex | reg 
plt.show()

# %% [markdown]
# ### **12. Swarm Plot**

# %%
sns.swarmplot(x='day', y='total_bill', data=df, size=10, legend=True, marker='*')
plt.title('Ditribution categoical Data')
plt.show()

# %% [markdown]
# ### **13. Strip Plot**

# %%
sns.stripplot(x='day', y='total_bill', data=df, size=10, marker='*')
plt.show()

# %% [markdown]
# ### **14. Combine Plot**

# %%
plt.figure(figsize=(12, 8))

plt.subplot(221)
sns.scatterplot(x='total_bill', y='tip', data=df)
plt.title('Scatter Plot of Total Bill vs Tip')

plt.subplot(2, 2, 2)
sns.boxplot(x='day', y='total_bill', data=df)
plt.title('Box Plot of Total Bill by Day')

plt.subplot(2, 2, 3)
sns.swarmplot(x='day', y='total_bill', data=df)
plt.title('Bar Plot of Total Bill by Day')

plt.subplot(2, 2, 4)
sns.histplot(df['total_bill'], kde=True)
plt.title('Histogram of Total Bill')

plt.tight_layout() # Improves the layout of the plots
plt.show()
